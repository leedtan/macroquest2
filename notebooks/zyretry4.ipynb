# %%
import pdb

# %%
# parts = [
#     b'SHOUT',b'4976f082-e1d0-d249-b6a0-b3ee5b96be5e',b'python',
#     b'priest',b'Execute',b'\x00\x00\x00\x06/bc hi']

# %%
import copy

# %%
try:
    from zyre_pyzmq import Zyre as Pyre
except Exception as e:
    print("using Python native module", e)
    from pyre import Pyre 

from pyre import zhelper 
import zmq 
import uuid
import logging
import sys
import json

n = Pyre("python")
n.set_header("blah1","SHOUT")
n.set_header("blah2",repr(n.uuid())[6:-2])
n.set_header("blah2",'brekt_jclerics')
n.set_header("blah2",'clr')
n.join("python")
n.start()
stuff = []
def chat_task(ctx, pipe):
    poller = zmq.Poller()
    poller.register(pipe, zmq.POLLIN)
    print(n.socket())
    poller.register(n.socket(), zmq.POLLIN)
    print(n.socket())
    while(True):
        items = dict(poller.poll())
        print(n.socket(), items)
        stuff.append(copy.copy(pipe))
        if pipe in items and items[pipe] == zmq.POLLIN:
            message = pipe.recv()
            # message to quit
            if message.decode('utf-8') == "$$STOP":
                break
            print("python_TASK: %s" % message)
            n.shouts("python", message.decode('utf-8'))
        else:
        #if n.socket() in items and items[n.socket()] == zmq.POLLIN:
            cmds = n.recv()
            msg_type = cmds.pop(0)
            print("NODE_MSG TYPE: %s" % msg_type)
            print("NODE_MSG PEER: %s" % uuid.UUID(bytes=cmds.pop(0)))
            print("NODE_MSG NAME: %s" % cmds.pop(0))
            if msg_type.decode('utf-8') == "SHOUT":
                print("NODE_MSG GROUP: %s" % cmds.pop(0))
            elif msg_type.decode('utf-8') == "ENTER":
                headers = json.loads(cmds.pop(0).decode('utf-8'))
                print("NODE_MSG HEADERS: %s" % headers)
                for key in headers:
                    print("key = {0}, value = {1}".format(key, headers[key]))
                
            print("NODE_MSG CONT: %s" % cmds)
    n.stop()


if __name__ == '__main__':
    # Create a StreamHandler for debugging
    logger = logging.getLogger("pyre")
    logger.setLevel(logging.INFO)
    logger.addHandler(logging.StreamHandler())
    logger.propagate = False

    ctx = zmq.Context()
    python_pipe = zhelper.zthread_fork(ctx, chat_task)
    # input in python 2 is different
    if sys.version_info.major < 3:
        input = raw_input

#     while True:
#         try:
#             msg = input()
#             python_pipe.send(msg.encode('utf_8'))
#         except (KeyboardInterrupt, SystemExit):
#             break
#     python_pipe.send("$$STOP".encode('utf_8'))
#     print("FINISHED")
# Out:
# using Python native module No module named 'zyre_pyzmq'
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}

# %%
repr(n.uuid())[6:-2]
# Out:
# NODE_MSG TYPE: b'ENTER'
# NODE_MSG PEER: 6a99e5a8-c141-cd4d-8c02-ce9aa3752da4
# NODE_MSG NAME: b'brekt_jbardq'
# NODE_MSG HEADERS: {'name': 'brekt_jbardq'}
# key = name, value = brekt_jbardq
# NODE_MSG CONT: [b'tcp://10.0.0.164:49186']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 6a99e5a8-c141-cd4d-8c02-ce9aa3752da4
# NODE_MSG NAME: b'brekt_jbardq'
# NODE_MSG CONT: [b'all']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 6a99e5a8-c141-cd4d-8c02-ce9aa3752da4
# NODE_MSG NAME: b'brekt_jbardq'
# NODE_MSG CONT: [b'brd']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 6a99e5a8-c141-cd4d-8c02-ce9aa3752da4
# NODE_MSG NAME: b'brekt_jbardq'
# NODE_MSG CONT: [b'group_brekt_jclericq']
# '57bef699-a643-4bb8-9c00-1d3da4558abe'
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 6a99e5a8-c141-cd4d-8c02-ce9aa3752da4
# NODE_MSG NAME: b'brekt_jbardq'
# NODE_MSG CONT: [b'melee']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 6a99e5a8-c141-cd4d-8c02-ce9aa3752da4
# NODE_MSG NAME: b'brekt_jbardq'
# NODE_MSG CONT: [b'raid_brekt_jclericb']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 6a99e5a8-c141-cd4d-8c02-ce9aa3752da4
# NODE_MSG NAME: b'brekt_jbardq'
# NODE_MSG CONT: [b'zone_brekt_poknowledge']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 6a99e5a8-c141-cd4d-8c02-ce9aa3752da4
# NODE_MSG NAME: b'brekt_jbardq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'ENTER'
# NODE_MSG PEER: 90501fb5-e1ee-e746-b46f-006f3579e6e0
# NODE_MSG NAME: b'brekt_jclerice'
# NODE_MSG HEADERS: {'name': 'brekt_jclerice'}
# key = name, value = brekt_jclerice
# NODE_MSG CONT: [b'tcp://10.0.0.164:49170']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 90501fb5-e1ee-e746-b46f-006f3579e6e0
# NODE_MSG NAME: b'brekt_jclerice'
# NODE_MSG CONT: [b'all']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 90501fb5-e1ee-e746-b46f-006f3579e6e0
# NODE_MSG NAME: b'brekt_jclerice'
# NODE_MSG CONT: [b'clr']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 90501fb5-e1ee-e746-b46f-006f3579e6e0
# NODE_MSG NAME: b'brekt_jclerice'
# NODE_MSG CONT: [b'group_brekt_jclerice']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 90501fb5-e1ee-e746-b46f-006f3579e6e0
# NODE_MSG NAME: b'brekt_jclerice'
# NODE_MSG CONT: [b'priest']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 90501fb5-e1ee-e746-b46f-006f3579e6e0
# NODE_MSG NAME: b'brekt_jclerice'
# NODE_MSG CONT: [b'raid_brekt_jclericb']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 90501fb5-e1ee-e746-b46f-006f3579e6e0
# NODE_MSG NAME: b'brekt_jclerice'
# NODE_MSG CONT: [b'zone_brekt_poknowledge']

# %%
n.join('python')
# Out:
# <pyre.zsocket.ZSocket object at 0x000001D1B44F1AC8> {<pyre.zsocket.ZSocket object at 0x000001D1B44F1AC8>: 1}
# NODE_MSG TYPE: b'SHOUT'
# NODE_MSG PEER: b6f72358-d6b3-a949-b276-89655c9071a4
# NODE_MSG NAME: b'brekt_jclerics'
# NODE_MSG GROUP: b'python'
# NODE_MSG CONT: [b'Execute', b'\x00\x00\x00\x02hi']
# <pyre.zsocket.ZSocket object at 0x000001D1B44F1AC8> {<pyre.zsocket.ZSocket object at 0x000001D1B44F1AC8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: b6f72358-d6b3-a949-b276-89655c9071a4
# NODE_MSG NAME: b'brekt_jclerics'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']

# %%
python_pipe.send_multipart([b'Execute', b'\x00\x00\x00\x02hi'])
# Out:
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<zmq.sugar.socket.Socket object at 0x0000020A088F9438>: 1}
# python_TASK: b'Execute'
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<zmq.sugar.socket.Socket object at 0x0000020A088F9438>: 1}
# python_TASK: b'\x00\x00\x00\x02hi'
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: b2510d32-b893-f54a-a5bb-b065f5ed3aec
# NODE_MSG NAME: b'brekt_jbards'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 395374be-09bb-4d40-a948-8b19e8d0c654
# NODE_MSG NAME: b'brekt_jrogueq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 3f255d84-aa25-aa46-b837-cd0f4936ae05
# NODE_MSG NAME: b'brekt_jberserkerm'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 4a8183ea-4dd7-b744-9e47-e5142f4de4e1
# NODE_MSG NAME: b'brekt_jrangerd'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 7721b08e-dfab-594a-b3e4-1b0c4cdbd9fe
# NODE_MSG NAME: b'brekt_jpaladins'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: ed5340ce-0590-894f-9089-3a25ffebc5d9
# NODE_MSG NAME: b'brekt_jwarriorq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 08b52810-eba8-3e4d-8628-3b79ac0ab50d
# NODE_MSG NAME: b'brekt_jmagp'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: fa2e839f-122c-1742-81df-86da57f4d536
# NODE_MSG NAME: b'brekt_jrangero'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 93208039-b610-294c-ae84-a909ef5b3b22
# NODE_MSG NAME: b'brekt_jberserkerq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: cd4a5574-6362-8342-be52-99c84c8cb41d
# NODE_MSG NAME: b'brekt_jshamanp'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: d21e4b0f-1b77-1448-9f40-f9a3ca819e01
# NODE_MSG NAME: b'brekt_jmage'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 1ee61369-b160-fd40-ad2e-3c793f05e897
# NODE_MSG NAME: b'brekt_jclericb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 05bea253-296e-0e4d-bda9-005864b7edb8
# NODE_MSG NAME: b'brekt_jclericd'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: fccbbcc8-16a4-2a42-9ba5-a390d644ba04
# NODE_MSG NAME: b'brekt_jencp'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: aa2b03b0-1233-f641-b444-41097ebda717
# NODE_MSG NAME: b'brekt_jrangers'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 9c09efe9-6c95-0445-abab-d6f412959a47
# NODE_MSG NAME: b'brekt_jrogueb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: a64bc3b5-9997-fb49-b1dd-cf9bf4f9efd7
# NODE_MSG NAME: b'brekt_jberserkerb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: d1a321c6-d1ad-8a4e-8274-97df32b187f5
# NODE_MSG NAME: b'brekt_jbarde'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 23d26997-ee95-324f-a95d-0944aeff7cb5
# NODE_MSG NAME: b'brekt_jbardo'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 247c9986-d15f-fe49-8af9-f654f5edb967
# NODE_MSG NAME: b'brekt_jbeastlordd'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: c62842b8-56e7-3947-b652-ff739d4d3923
# NODE_MSG NAME: b'brekt_jberserkerr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 1b73cc8d-9004-3443-a165-4b279164c75c
# NODE_MSG NAME: b'brekt_jmagd'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 323b1580-417c-d844-923c-7b33318ee16c
# NODE_MSG NAME: b'brekt_jbardd'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 450a854d-da96-9e4a-bd81-3d7017cf2ce7
# NODE_MSG NAME: b'brekt_jwarriord'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 12dde2d7-5499-0149-bb84-0c23e1f21e05
# NODE_MSG NAME: b'brekt_jroguer'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 1623d0bd-86b7-294c-b19e-3f25f69a2517
# NODE_MSG NAME: b'brekt_jshamane'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 55617c4b-f84d-644a-8cef-c9178ff49317
# NODE_MSG NAME: b'brekt_jbeastlordq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 54eaa7b7-b1b0-9946-bd6d-09539eac125b
# NODE_MSG NAME: b'brekt_jnecrop'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 17c4ab86-9a04-7945-bbd9-fd3183453d40
# NODE_MSG NAME: b'brekt_jmonkr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 951e6310-d6f4-a742-9d3e-2cf5e3d26b3a
# NODE_MSG NAME: b'brekt_jberserkers'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: b85a758d-1616-8d41-9c8f-c0aed6e180fb
# NODE_MSG NAME: b'brekt_jmonks'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 89a53407-5b39-d840-bec2-0c3ea5d8e63f
# NODE_MSG NAME: b'brekt_jbardr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 6a99e5a8-c141-cd4d-8c02-ce9aa3752da4
# NODE_MSG NAME: b'brekt_jbardq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 621e2702-a525-c941-a58c-42e12858583e
# NODE_MSG NAME: b'brekt_jclerico'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 5f0e9edb-0413-354d-826c-84d1cbeafcd8
# NODE_MSG NAME: b'brekt_jwizp'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 4209aecc-9f62-8a40-bef0-f411ca0f3551
# NODE_MSG NAME: b'brekt_jbeastlordr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 13f356ef-aa6c-4e48-9a37-535d28efe4d3
# NODE_MSG NAME: b'brekt_jclericq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 69401d6b-f6ea-4a44-967b-62a5f801b678
# NODE_MSG NAME: b'brekt_jbardp'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 6b4e386f-2bb9-9247-93ee-448efd874752
# NODE_MSG NAME: b'brekt_jberserkero'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 69d66d8e-4fe6-bd4b-a3d2-db815f0daf4a
# NODE_MSG NAME: b'brekt_jbardb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 5e61c8cc-f98e-7345-8a63-11edbe07c1b5
# NODE_MSG NAME: b'brekt_jpaladinb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 90501fb5-e1ee-e746-b46f-006f3579e6e0
# NODE_MSG NAME: b'brekt_jclerice'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: b1ee5372-f125-824e-bccc-635295ad2a7f
# NODE_MSG NAME: b'brekt_jshadowo'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 9625028c-9d85-a740-b80b-4a7cfca0bc38
# NODE_MSG NAME: b'brekt_jshamanb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 3a45a2b5-7972-8f44-a578-d7565d37ee6a
# NODE_MSG NAME: b'brekt_jrogueo'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 8ce97a86-c64a-5a47-9a2b-cab8f4149809
# NODE_MSG NAME: b'brekt_jenche'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 32131415-bd2a-3344-b50c-99f28f137a9c
# NODE_MSG NAME: b'brekt_jdruidr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: b6f72358-d6b3-a949-b276-89655c9071a4
# NODE_MSG NAME: b'brekt_jclerics'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: b6f72358-d6b3-a949-b276-89655c9071a4
# NODE_MSG NAME: b'brekt_jclerics'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 1ee61369-b160-fd40-ad2e-3c793f05e897
# NODE_MSG NAME: b'brekt_jclericb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: aa2b03b0-1233-f641-b444-41097ebda717
# NODE_MSG NAME: b'brekt_jrangers'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 69d66d8e-4fe6-bd4b-a3d2-db815f0daf4a
# NODE_MSG NAME: b'brekt_jbardb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 8ce97a86-c64a-5a47-9a2b-cab8f4149809
# NODE_MSG NAME: b'brekt_jenche'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 13f356ef-aa6c-4e48-9a37-535d28efe4d3
# NODE_MSG NAME: b'brekt_jclericq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 69401d6b-f6ea-4a44-967b-62a5f801b678
# NODE_MSG NAME: b'brekt_jbardp'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 6a99e5a8-c141-cd4d-8c02-ce9aa3752da4
# NODE_MSG NAME: b'brekt_jbardq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 4209aecc-9f62-8a40-bef0-f411ca0f3551
# NODE_MSG NAME: b'brekt_jbeastlordr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 3a45a2b5-7972-8f44-a578-d7565d37ee6a
# NODE_MSG NAME: b'brekt_jrogueo'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: b6f72358-d6b3-a949-b276-89655c9071a4
# NODE_MSG NAME: b'brekt_jclerics'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 32131415-bd2a-3344-b50c-99f28f137a9c
# NODE_MSG NAME: b'brekt_jdruidr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 1ee61369-b160-fd40-ad2e-3c793f05e897
# NODE_MSG NAME: b'brekt_jclericb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 951e6310-d6f4-a742-9d3e-2cf5e3d26b3a
# NODE_MSG NAME: b'brekt_jberserkers'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 90501fb5-e1ee-e746-b46f-006f3579e6e0
# NODE_MSG NAME: b'brekt_jclerice'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: aa2b03b0-1233-f641-b444-41097ebda717
# NODE_MSG NAME: b'brekt_jrangers'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 9625028c-9d85-a740-b80b-4a7cfca0bc38
# NODE_MSG NAME: b'brekt_jshamanb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 8ce97a86-c64a-5a47-9a2b-cab8f4149809
# NODE_MSG NAME: b'brekt_jenche'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 69d66d8e-4fe6-bd4b-a3d2-db815f0daf4a
# NODE_MSG NAME: b'brekt_jbardb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: b85a758d-1616-8d41-9c8f-c0aed6e180fb
# NODE_MSG NAME: b'brekt_jmonks'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 13f356ef-aa6c-4e48-9a37-535d28efe4d3
# NODE_MSG NAME: b'brekt_jclericq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 69401d6b-f6ea-4a44-967b-62a5f801b678
# NODE_MSG NAME: b'brekt_jbardp'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: d1a321c6-d1ad-8a4e-8274-97df32b187f5
# NODE_MSG NAME: b'brekt_jbarde'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 6a99e5a8-c141-cd4d-8c02-ce9aa3752da4
# NODE_MSG NAME: b'brekt_jbardq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 5e61c8cc-f98e-7345-8a63-11edbe07c1b5
# NODE_MSG NAME: b'brekt_jpaladinb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 5f0e9edb-0413-354d-826c-84d1cbeafcd8
# NODE_MSG NAME: b'brekt_jwizp'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 4209aecc-9f62-8a40-bef0-f411ca0f3551
# NODE_MSG NAME: b'brekt_jbeastlordr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: b1ee5372-f125-824e-bccc-635295ad2a7f
# NODE_MSG NAME: b'brekt_jshadowo'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 3a45a2b5-7972-8f44-a578-d7565d37ee6a
# NODE_MSG NAME: b'brekt_jrogueo'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 621e2702-a525-c941-a58c-42e12858583e
# NODE_MSG NAME: b'brekt_jclerico'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 323b1580-417c-d844-923c-7b33318ee16c
# NODE_MSG NAME: b'brekt_jbardd'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 32131415-bd2a-3344-b50c-99f28f137a9c
# NODE_MSG NAME: b'brekt_jdruidr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 17c4ab86-9a04-7945-bbd9-fd3183453d40
# NODE_MSG NAME: b'brekt_jmonkr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 951e6310-d6f4-a742-9d3e-2cf5e3d26b3a
# NODE_MSG NAME: b'brekt_jberserkers'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 90501fb5-e1ee-e746-b46f-006f3579e6e0
# NODE_MSG NAME: b'brekt_jclerice'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 12dde2d7-5499-0149-bb84-0c23e1f21e05
# NODE_MSG NAME: b'brekt_jroguer'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 1ee61369-b160-fd40-ad2e-3c793f05e897
# NODE_MSG NAME: b'brekt_jclericb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 9625028c-9d85-a740-b80b-4a7cfca0bc38
# NODE_MSG NAME: b'brekt_jshamanb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 8ce97a86-c64a-5a47-9a2b-cab8f4149809
# NODE_MSG NAME: b'brekt_jenche'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 450a854d-da96-9e4a-bd81-3d7017cf2ce7
# NODE_MSG NAME: b'brekt_jwarriord'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: b85a758d-1616-8d41-9c8f-c0aed6e180fb
# NODE_MSG NAME: b'brekt_jmonks'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 89a53407-5b39-d840-bec2-0c3ea5d8e63f
# NODE_MSG NAME: b'brekt_jbardr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: d1a321c6-d1ad-8a4e-8274-97df32b187f5
# NODE_MSG NAME: b'brekt_jbarde'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 54eaa7b7-b1b0-9946-bd6d-09539eac125b
# NODE_MSG NAME: b'brekt_jnecrop'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 5e61c8cc-f98e-7345-8a63-11edbe07c1b5
# NODE_MSG NAME: b'brekt_jpaladinb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 55617c4b-f84d-644a-8cef-c9178ff49317
# NODE_MSG NAME: b'brekt_jbeastlordq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 5f0e9edb-0413-354d-826c-84d1cbeafcd8
# NODE_MSG NAME: b'brekt_jwizp'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 55617c4b-f84d-644a-8cef-c9178ff49317
# NODE_MSG NAME: b'brekt_jbeastlordq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 54eaa7b7-b1b0-9946-bd6d-09539eac125b
# NODE_MSG NAME: b'brekt_jnecrop'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 17c4ab86-9a04-7945-bbd9-fd3183453d40
# NODE_MSG NAME: b'brekt_jmonkr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 69d66d8e-4fe6-bd4b-a3d2-db815f0daf4a
# NODE_MSG NAME: b'brekt_jbardb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: b1ee5372-f125-824e-bccc-635295ad2a7f
# NODE_MSG NAME: b'brekt_jshadowo'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 89a53407-5b39-d840-bec2-0c3ea5d8e63f
# NODE_MSG NAME: b'brekt_jbardr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 323b1580-417c-d844-923c-7b33318ee16c
# NODE_MSG NAME: b'brekt_jbardd'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 450a854d-da96-9e4a-bd81-3d7017cf2ce7
# NODE_MSG NAME: b'brekt_jwarriord'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 621e2702-a525-c941-a58c-42e12858583e
# NODE_MSG NAME: b'brekt_jclerico'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: aa2b03b0-1233-f641-b444-41097ebda717
# NODE_MSG NAME: b'brekt_jrangers'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 12dde2d7-5499-0149-bb84-0c23e1f21e05
# NODE_MSG NAME: b'brekt_jroguer'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 3a45a2b5-7972-8f44-a578-d7565d37ee6a
# NODE_MSG NAME: b'brekt_jrogueo'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 69401d6b-f6ea-4a44-967b-62a5f801b678
# NODE_MSG NAME: b'brekt_jbardp'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 6a99e5a8-c141-cd4d-8c02-ce9aa3752da4
# NODE_MSG NAME: b'brekt_jbardq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 9625028c-9d85-a740-b80b-4a7cfca0bc38
# NODE_MSG NAME: b'brekt_jshamanb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 13f356ef-aa6c-4e48-9a37-535d28efe4d3
# NODE_MSG NAME: b'brekt_jclericq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 951e6310-d6f4-a742-9d3e-2cf5e3d26b3a
# NODE_MSG NAME: b'brekt_jberserkers'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 32131415-bd2a-3344-b50c-99f28f137a9c
# NODE_MSG NAME: b'brekt_jdruidr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: fccbbcc8-16a4-2a42-9ba5-a390d644ba04
# NODE_MSG NAME: b'brekt_jencp'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 90501fb5-e1ee-e746-b46f-006f3579e6e0
# NODE_MSG NAME: b'brekt_jclerice'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 3f255d84-aa25-aa46-b837-cd0f4936ae05
# NODE_MSG NAME: b'brekt_jberserkerm'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: ed5340ce-0590-894f-9089-3a25ffebc5d9
# NODE_MSG NAME: b'brekt_jwarriorq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 5e61c8cc-f98e-7345-8a63-11edbe07c1b5
# NODE_MSG NAME: b'brekt_jpaladinb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 93208039-b610-294c-ae84-a909ef5b3b22
# NODE_MSG NAME: b'brekt_jberserkerq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: d1a321c6-d1ad-8a4e-8274-97df32b187f5
# NODE_MSG NAME: b'brekt_jbarde'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 395374be-09bb-4d40-a948-8b19e8d0c654
# NODE_MSG NAME: b'brekt_jrogueq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 17c4ab86-9a04-7945-bbd9-fd3183453d40
# NODE_MSG NAME: b'brekt_jmonkr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: b2510d32-b893-f54a-a5bb-b065f5ed3aec
# NODE_MSG NAME: b'brekt_jbards'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 12dde2d7-5499-0149-bb84-0c23e1f21e05
# NODE_MSG NAME: b'brekt_jroguer'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 621e2702-a525-c941-a58c-42e12858583e
# NODE_MSG NAME: b'brekt_jclerico'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 323b1580-417c-d844-923c-7b33318ee16c
# NODE_MSG NAME: b'brekt_jbardd'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 450a854d-da96-9e4a-bd81-3d7017cf2ce7
# NODE_MSG NAME: b'brekt_jwarriord'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 05bea253-296e-0e4d-bda9-005864b7edb8
# NODE_MSG NAME: b'brekt_jclericd'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 55617c4b-f84d-644a-8cef-c9178ff49317
# NODE_MSG NAME: b'brekt_jbeastlordq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 23d26997-ee95-324f-a95d-0944aeff7cb5
# NODE_MSG NAME: b'brekt_jbardo'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: c62842b8-56e7-3947-b652-ff739d4d3923
# NODE_MSG NAME: b'brekt_jberserkerr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 9c09efe9-6c95-0445-abab-d6f412959a47
# NODE_MSG NAME: b'brekt_jrogueb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 54eaa7b7-b1b0-9946-bd6d-09539eac125b
# NODE_MSG NAME: b'brekt_jnecrop'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: a64bc3b5-9997-fb49-b1dd-cf9bf4f9efd7
# NODE_MSG NAME: b'brekt_jberserkerb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 6b4e386f-2bb9-9247-93ee-448efd874752
# NODE_MSG NAME: b'brekt_jberserkero'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 4a8183ea-4dd7-b744-9e47-e5142f4de4e1
# NODE_MSG NAME: b'brekt_jrangerd'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: fa2e839f-122c-1742-81df-86da57f4d536
# NODE_MSG NAME: b'brekt_jrangero'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 247c9986-d15f-fe49-8af9-f654f5edb967
# NODE_MSG NAME: b'brekt_jbeastlordd'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: b1ee5372-f125-824e-bccc-635295ad2a7f
# NODE_MSG NAME: b'brekt_jshadowo'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 89a53407-5b39-d840-bec2-0c3ea5d8e63f
# NODE_MSG NAME: b'brekt_jbardr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 7721b08e-dfab-594a-b3e4-1b0c4cdbd9fe
# NODE_MSG NAME: b'brekt_jpaladins'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 1623d0bd-86b7-294c-b19e-3f25f69a2517
# NODE_MSG NAME: b'brekt_jshamane'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 5f0e9edb-0413-354d-826c-84d1cbeafcd8
# NODE_MSG NAME: b'brekt_jwizp'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: cd4a5574-6362-8342-be52-99c84c8cb41d
# NODE_MSG NAME: b'brekt_jshamanp'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: b85a758d-1616-8d41-9c8f-c0aed6e180fb
# NODE_MSG NAME: b'brekt_jmonks'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'JOIN'
# NODE_MSG PEER: 08b52810-eba8-3e4d-8628-3b79ac0ab50d
# NODE_MSG NAME: b'brekt_jmagp'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: a64bc3b5-9997-fb49-b1dd-cf9bf4f9efd7
# NODE_MSG NAME: b'brekt_jberserkerb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: fa2e839f-122c-1742-81df-86da57f4d536
# NODE_MSG NAME: b'brekt_jrangero'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 247c9986-d15f-fe49-8af9-f654f5edb967
# NODE_MSG NAME: b'brekt_jbeastlordd'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 1623d0bd-86b7-294c-b19e-3f25f69a2517
# NODE_MSG NAME: b'brekt_jshamane'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 13f356ef-aa6c-4e48-9a37-535d28efe4d3
# NODE_MSG NAME: b'brekt_jclericq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 5f0e9edb-0413-354d-826c-84d1cbeafcd8
# NODE_MSG NAME: b'brekt_jwizp'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 55617c4b-f84d-644a-8cef-c9178ff49317
# NODE_MSG NAME: b'brekt_jbeastlordq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: b2510d32-b893-f54a-a5bb-b065f5ed3aec
# NODE_MSG NAME: b'brekt_jbards'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 323b1580-417c-d844-923c-7b33318ee16c
# NODE_MSG NAME: b'brekt_jbardd'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: b6f72358-d6b3-a949-b276-89655c9071a4
# NODE_MSG NAME: b'brekt_jclerics'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 9c09efe9-6c95-0445-abab-d6f412959a47
# NODE_MSG NAME: b'brekt_jrogueb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 3f255d84-aa25-aa46-b837-cd0f4936ae05
# NODE_MSG NAME: b'brekt_jberserkerm'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 5e61c8cc-f98e-7345-8a63-11edbe07c1b5
# NODE_MSG NAME: b'brekt_jpaladinb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 3a45a2b5-7972-8f44-a578-d7565d37ee6a
# NODE_MSG NAME: b'brekt_jrogueo'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 17c4ab86-9a04-7945-bbd9-fd3183453d40
# NODE_MSG NAME: b'brekt_jmonkr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 69d66d8e-4fe6-bd4b-a3d2-db815f0daf4a
# NODE_MSG NAME: b'brekt_jbardb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: b1ee5372-f125-824e-bccc-635295ad2a7f
# NODE_MSG NAME: b'brekt_jshadowo'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: fccbbcc8-16a4-2a42-9ba5-a390d644ba04
# NODE_MSG NAME: b'brekt_jencp'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: ed5340ce-0590-894f-9089-3a25ffebc5d9
# NODE_MSG NAME: b'brekt_jwarriorq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 621e2702-a525-c941-a58c-42e12858583e
# NODE_MSG NAME: b'brekt_jclerico'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: cd4a5574-6362-8342-be52-99c84c8cb41d
# NODE_MSG NAME: b'brekt_jshamanp'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 450a854d-da96-9e4a-bd81-3d7017cf2ce7
# NODE_MSG NAME: b'brekt_jwarriord'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 69401d6b-f6ea-4a44-967b-62a5f801b678
# NODE_MSG NAME: b'brekt_jbardp'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 89a53407-5b39-d840-bec2-0c3ea5d8e63f
# NODE_MSG NAME: b'brekt_jbardr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 6a99e5a8-c141-cd4d-8c02-ce9aa3752da4
# NODE_MSG NAME: b'brekt_jbardq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 395374be-09bb-4d40-a948-8b19e8d0c654
# NODE_MSG NAME: b'brekt_jrogueq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: b85a758d-1616-8d41-9c8f-c0aed6e180fb
# NODE_MSG NAME: b'brekt_jmonks'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 93208039-b610-294c-ae84-a909ef5b3b22
# NODE_MSG NAME: b'brekt_jberserkerq'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 6b4e386f-2bb9-9247-93ee-448efd874752
# NODE_MSG NAME: b'brekt_jberserkero'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 90501fb5-e1ee-e746-b46f-006f3579e6e0
# NODE_MSG NAME: b'brekt_jclerice'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: aa2b03b0-1233-f641-b444-41097ebda717
# NODE_MSG NAME: b'brekt_jrangers'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 951e6310-d6f4-a742-9d3e-2cf5e3d26b3a
# NODE_MSG NAME: b'brekt_jberserkers'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 05bea253-296e-0e4d-bda9-005864b7edb8
# NODE_MSG NAME: b'brekt_jclericd'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 12dde2d7-5499-0149-bb84-0c23e1f21e05
# NODE_MSG NAME: b'brekt_jroguer'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 23d26997-ee95-324f-a95d-0944aeff7cb5
# NODE_MSG NAME: b'brekt_jbardo'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 54eaa7b7-b1b0-9946-bd6d-09539eac125b
# NODE_MSG NAME: b'brekt_jnecrop'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 8ce97a86-c64a-5a47-9a2b-cab8f4149809
# NODE_MSG NAME: b'brekt_jenche'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 4a8183ea-4dd7-b744-9e47-e5142f4de4e1
# NODE_MSG NAME: b'brekt_jrangerd'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 1ee61369-b160-fd40-ad2e-3c793f05e897
# NODE_MSG NAME: b'brekt_jclericb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 08b52810-eba8-3e4d-8628-3b79ac0ab50d
# NODE_MSG NAME: b'brekt_jmagp'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 9625028c-9d85-a740-b80b-4a7cfca0bc38
# NODE_MSG NAME: b'brekt_jshamanb'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: d1a321c6-d1ad-8a4e-8274-97df32b187f5
# NODE_MSG NAME: b'brekt_jbarde'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 7721b08e-dfab-594a-b3e4-1b0c4cdbd9fe
# NODE_MSG NAME: b'brekt_jpaladins'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: c62842b8-56e7-3947-b652-ff739d4d3923
# NODE_MSG NAME: b'brekt_jberserkerr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']
# <pyre.zsocket.ZSocket object at 0x0000020A088AC0B8> {<pyre.zsocket.ZSocket object at 0x0000020A088AC0B8>: 1}
# NODE_MSG TYPE: b'LEAVE'
# NODE_MSG PEER: 32131415-bd2a-3344-b50c-99f28f137a9c
# NODE_MSG NAME: b'brekt_jdruidr'
# NODE_MSG CONT: [b'brekt_jclericb_6029354']

# %%
# stuff

# %%
# n.shouts('python', 'hi')
